# %% [raw]
# ---
# description: Convolution Neural Networks (coming soon)
# output-file: cnns.html
# title: Convolution Neural Networks
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
