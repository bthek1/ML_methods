# %% [raw]
# ---
# description: K-NN
# output-file: k-nn.html
# title: K-NN
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(sayhello)
# Out:
# ---
#
# [source](https://github.com/bthek1/ML/blob/main/ML/knn.py#L8){target="_blank" style="float:right; font-size:smaller"}
#
# ### sayhello
#
# >      sayhello (name)
