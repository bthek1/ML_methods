# %% [raw]
# ---
# description: Machine Learning
# output-file: index.html
# title: '[ML](https://bthek1.github.io/ML/)'
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Step for git push

# %% [markdown]
# - nbdev_prepare

# %% [markdown]
# ```sh
# nbdev_prepare
# ```

# %% [markdown]
# - Git stuff

# %% [markdown]
# ```sh
# git add .
# git commit -m "update"
# git push
# ```

# %% [markdown]
# ## After changing dependencies

# %% [markdown]
# ```sh
# pip install ML
# ```

# %% [markdown]
# ```sh
# pip install -e '.[dev]'
# ```
