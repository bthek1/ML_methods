# %% [raw]
# ---
# description: Non-linear Input Transformations and Kernels
# output-file: kernals.html
# title: Kernels
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
